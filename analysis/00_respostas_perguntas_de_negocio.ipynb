# %% [markdown]
# # Perguntas
#
# Este notebook possíbilita consultas em qualquer camada no nosso Lake, além de tazer a respostas para as duas perguntas de negócio que foram solicitadas.
#
# ## Objetivos
#
# - Disponibilizar a tabelas gold para consulta.
# - Responder as duas perguntas solicitadas pelos stakeholders.

# %% [markdown]
# ---

# %% [markdown]
# ## Resposta pergunta 1

# %% [markdown]
# #### Qual a média de valor total (total\_amount) recebido em um mês considerando todos os yellow táxis da frota?

# %%
display(
    spark.table("workspace.ifood_case.gold_avg_total_amount_by_month")
)

# %% [markdown]
# ---

# %% [markdown]
# ## Resposta pergunta 2

# %% [markdown]
# #### Qual a média de passageiros (passenger_count) por cada hora do dia que pegaram táxi no mês de maio considerando todos os táxis da frota?

# %%
display(
    spark.table("workspace.ifood_case.gold_avg_passenger_count_may_by_hour")
)
