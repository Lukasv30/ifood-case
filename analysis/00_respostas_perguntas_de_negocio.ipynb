# %% [markdown]
# # Gold SQL Explorer
#
# Este notebook permite consultar a camada Gold criada para o case técnico, além de tazer a respostas para as duas perguntas de negócio que foram solicitadas.
#
# A camada Gold representa a camada de consumo analítico e contém tabelas preparadas para responder às perguntas propostas no desafio.
#
# Tabelas disponíveis:
#
# - `workspace.ifood_case.gold_yellow_taxi_trips`
# - `workspace.ifood_case.gold_avg_total_amount_by_month`
# - `workspace.ifood_case.gold_avg_passenger_count_may_by_hour`
#
# Por segurança, este notebook aceita apenas consultas de leitura (`SELECT` ou `WITH`) sobre tabelas da camada Gold.

# %% [markdown]
# ---

# %% [markdown]
# ## 01. Resposta pergunta 1

# %% [markdown]
# #### Qual a média de valor total (total\_amount) recebido em um mês considerando todos os yellow táxis da frota?

# %%
display(
    spark.table("workspace.ifood_case.gold_avg_total_amount_by_month")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>pickup_year</th><th>pickup_month</th><th>avg_total_amount</th><th>trip_count</th></tr></thead><tbody><tr><td>2023</td><td>1</td><td>27.46</td><td>2917665</td></tr><tr><td>2023</td><td>2</td><td>27.37</td><td>2764200</td></tr><tr><td>2023</td><td>3</td><td>28.28</td><td>3226999</td></tr><tr><td>2023</td><td>4</td><td>28.78</td><td>3109876</td></tr><tr><td>2023</td><td>5</td><td>29.45</td><td>3319397</td></tr></tbody></table></div>

# %% [markdown]
# ---

# %% [markdown]
# ## 02. Resposta pergunta 2

# %% [markdown]
# #### Qual a média de passageiros (passenger_count) por cada hora do dia que pegaram táxi no mês de maio considerando todos os táxis da frota?

# %%
display(
    spark.table("workspace.ifood_case.gold_avg_passenger_count_may_by_hour")
)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# ...

# %% [markdown]
# ___
